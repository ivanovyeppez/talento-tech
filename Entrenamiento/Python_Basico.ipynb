# %% [markdown]
# <a href="https://colab.research.google.com/github/ivanovyeppez/talento-tech/blob/main/Entrenamiento/Python_Basico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐍 Python Básico — Cuaderno didáctico
# **Objetivo:** Aprender Python desde cero, con ejemplos simples y ejercicios prácticos.
# **Perfil:** Para cualquier profesión y edad — lenguaje claro, paso a paso.
# **Cómo usar este cuaderno:** Ejecuta las celdas con ▶️ (Shift+Enter en Jupyter / Colab).
#
# By. **Ing. Engler González**
#
# > Consejo: si algo no corre a la primera, ¡no pasa nada! Lee el mensaje de error, ajusta y vuelve a intentar.

# %% [markdown]
# ## 1. Primeros pasos con Python
# Aprenderás:
# - Mostrar mensajes por pantalla (`print`)
# - Comentarios (`#`)
# - Variables y tipos básicos
# - Operadores

# %%
# @title Default title text
# Hola, mundo
print("¡Hola, mundo!")  # Esto es un comentario: el programa no lo ejecuta
# Out:
# ¡Hola, mundo!

# %%
# Variables y tipos datos
a = 1

nombre = "Alex"
edad = 20
altura_m = 1.72
es_estudiante = True

num = 123
print(num * 2)


print(type(nombre), type(edad), type(altura_m), type(es_estudiante))
# Out:
# 246
# <class 'str'> <class 'int'> <class 'float'> <class 'bool'>

# %%
# Operadores aritméticos y de comparación
a, b = 7, 3
print("Suma:", a + b)
print("Resta:", a - b)
print("Multiplicación:", a * b)
print("División:", a / b)
print("División entera:", a // b)
print("Módulo:", a % b)
print("Potencia:", a ** b)
print("¿a > b?", a > b)
print("¿a == b?", a == b)
# Out:
# Suma: 10
# Resta: 4
# Multiplicación: 21
# División: 2.3333333333333335
# División entera: 2
# Módulo: 1
# Potencia: 343
# ¿a > b? True
# ¿a == b? False

# %% [markdown]
# ### 🧪 Ejercicios (1)
# 1. Crea variables para tu **nombre**, **edad** y **ciudad**, y muéstralas con `print` en una sola línea.
# 2. Dados `x=15` y `y=4`, calcula: suma, resta, multiplicación, división, división entera, módulo y potencia.
# 3. ¿Qué tipo de dato es `3.0`? ¿y `"3"`? Compruébalo con `type()`.

# %%
# Tu solución aquí
nombre = "Ivan"
edad = 41
ciudad = "Pasto"
print("\n----------------------------------------")
print(nombre, edad, ciudad)
print("\n----------------------------------------")
x = 15
y = 4
print("Suma:", x + y)
print("Resta:", x - y)
print("Multiplicación:", x * y)
print("División:", x / y)
print("División entera:", x // y)
print("Módulo:", x % y)
print("Potencia:", x ** y)
print("\n----------------------------------------")
print(type(3.0))
print(type("3"))
# Out:
# ----------------------------------------
# Ivan 41 Pasto
#
# ----------------------------------------
# Suma: 19
# Resta: 11
# Multiplicación: 60
# División: 3.75
# División entera: 3
# Módulo: 3
# Potencia: 50625
#
# ----------------------------------------
# <class 'float'>
# <class 'str'>

# %% [markdown]
# ## 2. Números y Cadenas (strings)

# %%
# Números
entero = 42
decimal = 3.14159
print(entero + 8, decimal * 2)
# Out:
# 50 6.28318

# %%
# Cadenas (strings)
frase = "Aprender Python es divertido"
print(frase)
print(frase.upper())
print(frase.lower())
print(frase.title())
print(frase[:8], "|", frase[-9:])  # slicing
# Out:
# Aprender Python es divertido
# APRENDER PYTHON ES DIVERTIDO
# aprender python es divertido
# Aprender Python Es Divertido
# Aprender | divertido

# %%
# f-strings (formato amigable)
nombre = "Ivan"
edad = 41
print(f"Hola, me llamo {nombre} y tengo {edad} años.")
# Out:
# Hola, me llamo Ivan y tengo 41 años.

# %% [markdown]
# ### 🧪 Ejercicios (2)
# 1. Dada la cadena `texto = "  datos LIMPIOS  "`, muestra:
#    - Sin espacios al inicio/fin
#    - En minúsculas
#    - Reemplaza `"limpios"` por `"ordenados"` (sin importar mayúsculas)
# 2. Usa un **f-string** para construir: `Mi producto favorito es X y cuesta Y pesos`.

# %%
# Tu solución aquí
texto = "  datos LIMPIOS  "
print(texto.strip())
print(texto.lower())
print(texto.lower().replace("limpios", "ordenados"))

producto = "laptop"
precio = 12000
print(f"Mi producto favorito es {producto} y cuesta {precio} pesos.")
# Out:
# datos LIMPIOS
#   datos limpios
#   datos ordenados
# Mi producto favorito es laptop y cuesta 12000 pesos.

# %% [markdown]
# ## 3. Estructuras de datos
# Aprenderás las colecciones más usadas:
# - **Listas**: ordenadas y mutables
# - **Tuplas**: ordenadas e inmutables
# - **Conjuntos (set)**: sin orden, sin duplicados
# - **Diccionarios**: pares clave–valor

# %%
# Listas
numeros = [10, 20, 30]
numeros.append(40)
numeros.append(50)
numeros[1] = 25
print("Lista:", numeros, "Largo:", len(numeros))
# Out:
# Lista: [10, 25, 30, 40, 50] Largo: 5

# %%
# Tuplas (como listas que NO cambian)
coordenada = (3, 5)
print(coordenada, coordenada[0])
# Out:
# (3, 5) 3

# %%
# Conjuntos (sets): eliminan duplicados automáticamente
ciudades = {"Bogotá", "Cali", "Bogotá", "Medellín"}
print(ciudades)
ciudades.add("Barranquilla")
print(ciudades)
# Out:
# {'Medellín', 'Bogotá', 'Cali'}
# {'Medellín', 'Bogotá', 'Barranquilla', 'Cali'}

# %%
# Diccionarios (clave -> valor)
persona = {"nombre": "Alex", "edad": 20, "ciudad": "Pasto"}
persona["edad"] = 21
persona["profesion"] = "Diseño"
print(persona)
print("Claves:", list(persona.keys()))
print("Valores:", list(persona.values()))
# Out:
# {'nombre': 'Alex', 'edad': 21, 'ciudad': 'Pasto', 'profesion': 'Diseño'}
# Claves: ['nombre', 'edad', 'ciudad', 'profesion']
# Valores: ['Alex', 21, 'Pasto', 'Diseño']

# %%
# Comprensiones (listas y diccionarios en una sola línea)
cuadrados = [n*n for n in range(6)]
cuad = {n: n*n for n in range(6)}
cuadrados_pares = {n: n*n for n in range(10) if n % 2 == 0}
print(cuadrados)
print(cuad)
print(cuadrados_pares)
# Out:
# [0, 1, 4, 9, 16, 25]
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %% [markdown]
# ### 🧪 Ejercicios (3)
# 1. Crea una lista con 5 frutas y:
#    - Añade una fruta
#    - Ordena la lista
#    - Muestra la primera y la última
# 2. Convierte la lista `["a", "b", "a", "c", "b"]` a un **set** y cuenta cuántos valores únicos hay.
# 3. Crea un diccionario `precios` con 3 productos y sus precios. Aumenta todos los precios 10% usando una **comprensión**.

# %%
# Tu solución aquí
# Lista con 5 frutas
frutas = ["manzana", "pera", "banano", "uva", "naranja"]
print(frutas)

# Añadir una fruta
frutas.append("mango")

print(frutas)

# Ordenar la lista
frutas.sort()
print(frutas)

# Mostrar la primera y la última
print("Primera fruta:", frutas[0])
print("Última fruta:", frutas[-1])

# Convertir lista a set y contar valores únicos
valores = ["a", "b", "a", "c", "b"]
valores_unicos = set(valores)
print("Valores únicos:", valores_unicos)
print("Cantidad de únicos:", len(valores_unicos))

# Diccionario de precios
precios = {"arroz": 2500, "leche": 3200, "pan": 1800}

# Aumentar todos los precios 10% con comprensión
precios_actualizados = {producto: precio * 1.1 for producto, precio in precios.items()}

print("Precios actualizados:", precios_actualizados)
# Out:
# ['manzana', 'pera', 'banano', 'uva', 'naranja']
# ['manzana', 'pera', 'banano', 'uva', 'naranja', 'mango']
# ['banano', 'mango', 'manzana', 'naranja', 'pera', 'uva']
# Primera fruta: banano
# Última fruta: uva
# Valores únicos: {'c', 'b', 'a'}
# Cantidad de únicos: 3
# Precios actualizados: {'arroz': 2750.0, 'leche': 3520.0000000000005, 'pan': 1980.0000000000002}

# %% [markdown]
# ## 4. Control de flujo: condicionales y bucles

# %%
# if / elif / else
nota = 85
if nota >= 90:
    print("Excelente")
elif nota >= 70:
    print("Bien")
else:
    print("Necesita repasar")
# Out:
# Bien

# %%
# for y while
for i in range(1, 6):
    print("Número:", i)

n = 5
while n > 0:
    print("Cuenta:", n)
    n -= 1
# Out:
# Número: 1
# Número: 2
# Número: 3
# Número: 4
# Número: 5
# Cuenta: 5
# Cuenta: 4
# Cuenta: 3
# Cuenta: 2
# Cuenta: 1

# %%
# break y continue
for i in range(10):
    if i == 3:
        continue  # salta el 3
    if i == 8:
        break     # termina el bucle
    print(i, end=" ")
# Out:
# 0 1 2 4 5 6 7

# %% [markdown]
# ### 🧪 Ejercicios (4)
# 1. Pide (simulado) una `edad` en una variable y clasifica: *niño* (<12), *adolescente* (12-17), *adulto* (18-64), *mayor* (65+).
# 2. Imprime los números del 1 al 100, pero:
#    - si es múltiplo de 3, imprime **Fizz**
#    - si es múltiplo de 5, imprime **Buzz**
#    - si es múltiplo de ambos, **FizzBuzz**

# %%
# Tu solución aquí
# Simulación de pedir la edad
edad = 17  # puedes cambiar este valor para probar

# Clasificación
if edad < 12:
    print("Niño")
elif 12 <= edad <= 17:
    print("Adolescente")
elif 18 <= edad <= 64:
    print("Adulto")
else:
    print("Mayor")

# FizzBuzz del 1 al 100
for i in range(1, 101):
    if i % 3 == 0 and i % 5 == 0:
        print("FizzBuzz")
    elif i % 3 == 0:
        print("Fizz")
    elif i % 5 == 0:
        print("Buzz")
    else:
        print(i)
# Out:
# Adolescente
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %% [markdown]
# ## 5. Funciones

# %%
def saludo(nombre="mundo"):
    """Devuelve un saludo amable."""
    return f"Hola, {nombre}!"

print(saludo(), saludo("Ivan"))
# Out:
# Hola, mundo! Hola, Ivan!

# %%
# Parámetros variables (*args, **kwargs)
def sumar(*nums):
    return sum(nums)

def mostrar_info(**datos):
    return ", ".join(f"{k}={v}" for k, v in datos.items())

print(sumar(1,2,3,4))
print(mostrar_info(nombre="Ivan", edad=41))
# Out:
# 10
# nombre=Ivan, edad=41

# %% [markdown]
# ### 🧪 Ejercicios (5)
# 1. Escribe una función `es_par(n)` que devuelva `True/False`.
# 2. Escribe `promedio(lista)` que calcule el promedio sin usar librerías.
# 3. Escribe `contar_palabras(texto)` que devuelva un diccionario `{palabra: apariciones}`.

# %%
# Tu solución aquí
# Función que determina si un número es par
def es_par(n):
    return n % 2 == 0

# Función que calcula el promedio de una lista
def promedio(lista):
    if len(lista) == 0:
        return 0
    return sum(lista) / len(lista)

# Función que cuenta las palabras en un texto
def contar_palabras(texto):
    palabras = texto.split()
    conteo = {}
    for p in palabras:
        p = p.lower()  # normalizar a minúsculas
        conteo[p] = conteo.get(p, 0) + 1
    return conteo


# Ejemplos de uso:
print(es_par(4))             # True
print(es_par(7))             # False

print(promedio([10, 20, 30]))  # 20.0

texto = "hola mundo hola python mundo"
print(contar_palabras(texto))
# {'hola': 2, 'mundo': 2, 'python': 1}
# Out:
# True
# False
# 20.0
# {'hola': 2, 'mundo': 2, 'python': 1}

# %% [markdown]
# ## 6. Módulos y paquetes

# %%
import math, random

print("Raíz de 81:", math.isqrt(81))
print("Número aleatorio [0,1):", random.random())
print("Elección aleatoria:", random.choice(["rojo","verde","azul"]))
# Out:
# Raíz de 81: 9
# Número aleatorio [0,1): 0.8814977170648092
# Elección aleatoria: azul

# %% [markdown]
# ### 🧪 Ejercicios (6)
# 1. Usa `math` para calcular el área de un círculo de radio 7.
# 2. Con `random`, simula 10 lanzamientos de moneda (cara/cruz) y cuenta resultados.

# %%
# Tu solución aquí
import math
import random

# Área de un círculo de radio 7
radio = 7
area = math.pi * radio**2
print("Área del círculo:", area)

# Simulación de 10 lanzamientos de moneda
resultados = {"cara": 0, "cruz": 0}
for _ in range(10):
    lanzamiento = random.choice(["cara", "cruz"])
    resultados[lanzamiento] += 1

print("Resultados:", resultados)
# Out:
# Área del círculo: 153.93804002589985
# Resultados: {'cara': 3, 'cruz': 7}

# %% [markdown]
# ## 7. Manejo de errores (excepciones)

# %%
def dividir(a, b):
    try:
        return a / b
    except ZeroDivisionError:
        return "No se puede dividir por cero"
    except TypeError:
        return "Tipos no válidos (usa números)"
    finally:
        pass  # lugar para liberar recursos si hiciera falta

print(dividir(10, 2))
print(dividir(10, 0))
print(dividir(10, "x"))
# Out:
# 5.0
# No se puede dividir por cero
# Tipos no válidos (usa números)

# %% [markdown]
# ### 🧪 Ejercicios (7)
# 1. Crea una función `leer_entero(texto)` que intente convertir `texto` a entero.
#    - Si falla, devuelve `None` y muestra un mensaje amigable.

# %%
# Tu solución aquí
def leer_entero(texto):
    try:
        return int(texto)
    except ValueError:
        print("No se pudo convertir a entero.")
        return None


# Ejemplos
print(leer_entero("123"))   # 123
print(leer_entero("abc"))   # None, muestra mensaje
# Out:
# 123
# No se pudo convertir a entero.
# None

# %% [markdown]
# ## 8. Archivos (texto)
# > En Colab, los archivos se guardan temporalmente. Si quieres conservarlos, descárgalos o súbelos a Drive.

# %%
# Escribir y leer un archivo
contenido = "Líneas de ejemplo\nLínea 2\nLínea 3"
with open("ejemplo.txt", "w", encoding="utf-8") as f:
    f.write(contenido)

with open("ejemplo.txt", "r", encoding="utf-8") as f:
    texto = f.read()

print(texto)
# Out:
# Líneas de ejemplo
# Línea 2
# Línea 3

# %% [markdown]
# ### 🧪 Ejercicios (8)
# 1. Escribe un archivo `notas.txt` con 3 líneas de texto.
# 2. Léelo y cuenta cuántas líneas y cuántas palabras totales tiene.

# %%
# Tu solución aquí

# %% [markdown]
# ## 9. Bonus: Numpy y Matplotlib (visualización básica)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 10, 1)
y = x * x

plt.figure()
plt.plot(x, y)
plt.title("Cuadrados de 0 a 9")
plt.xlabel("x")
plt.ylabel("x^2")
plt.show()

# %% [markdown]
# ## 10. Mini-proyectos (elige 1 o haz ambos)
# ### A) Juego: Adivina el número
# - La computadora elige un número secreto entre 1 y 100.
# - Tú intentas adivinarlo; recibe pistas: "mayor/menor".
#
# ### B) Presupuesto semanal
# - Ingresa ingresos y gastos por categorías.
# - Calcula el balance y muestra un resumen.

# %%
# A) Adivina el número (versión automática para no depender de input en Colab)
import random

secreto = random.randint(1, 100)
intentos = 0

# Simulamos "intentos" de 1 a 100 hasta acertar, mostrando la lógica
for guess in range(1, 101):
    intentos += 1
    if guess < secreto:
        pass  # pista: es mayor
    elif guess > secreto:
        pass  # pista: es menor
    else:
        print(f"¡Acertado! El número era {secreto}. Intentos: {intentos}")
        break
# Out:
# ¡Acertado! El número era 24. Intentos: 24

# %%
# B) Presupuesto semanal (datos de ejemplo)
ingresos = {"salario": 500, "freelance": 150}
gastos = {"comida": 120, "transporte": 40, "servicios": 90, "ocio": 60}

total_ingresos = sum(ingresos.values())
total_gastos = sum(gastos.values())
balance = total_ingresos - total_gastos

print("Ingresos:", ingresos, "=>", total_ingresos)
print("Gastos:", gastos, "=>", total_gastos)
print("Balance semanal:", balance)
# Out:
# Ingresos: {'salario': 500, 'freelance': 150} => 650
# Gastos: {'comida': 120, 'transporte': 40, 'servicios': 90, 'ocio': 60} => 310
# Balance semanal: 340

# %% [markdown]
# ## 11. Mini-quiz (auto-evaluación)
# 1. ¿Qué tipo de dato devuelve `input()`?
# 2. ¿Cuál es la diferencia entre lista y tupla?
# 3. ¿Para qué sirve un `try/except`?
# 4. Escribe una **comprensión** que cree una lista con los cubos de 0 a 5.
# 5. ¿Qué imprime `print(type(True))`?

# %%
# Responde aquí (comentarios):
# Pregunta 1: ¿Qué tipo de dato devuelve input()?
dato = "123"   # Simulamos como si fuera input("Ingrese algo: ")
print(type(dato))   # Respuesta: <class 'str'>

# Pregunta 2: Diferencia entre lista y tupla
lista = [1, 2, 3]
tupla = (1, 2, 3)

lista[0] = 99   # Esto funciona porque lista es mutable
print("Lista modificada:", lista)

# tupla[0] = 99  # Esto daría error, porque la tupla es inmutable
print("Tupla (inmutable):", tupla)


# Pregunta 3: Uso de try/except
try:
    num = int("abc")  # Esto genera ValueError
except ValueError:
    print("Ocurrió un error al convertir, pero el programa no se detuvo.")


# Pregunta 4: Comprensión de lista con cubos de 0 a 5
cubos = [x**3 for x in range(6)]
print("Cubos de 0 a 5:", cubos)


# Pregunta 5: type(True)
print(type(True))
# Out:
# <class 'str'>
# Lista modificada: [99, 2, 3]
# Tupla (inmutable): (1, 2, 3)
# Ocurrió un error al convertir, pero el programa no se detuvo.
# Cubos de 0 a 5: [0, 1, 8, 27, 64, 125]
# <class 'bool'>

# %% [markdown]
# ## 12. Soluciones (haz clic para desplegar)
# <details>
# <summary><strong>Ejercicios (1 → 8)</strong></summary>
#
# **(1)**
# ```python
# nombre, edad, ciudad = "Alex", 20, "Pasto"
# print(nombre, edad, ciudad)
# x, y = 15, 4
# print(x+y, x-y, x*y, x/y, x//y, x%y, x**y)
# print(type(3.0), type("3"))
# ```
#
# **(2)**
# ```python
# texto = "  datos LIMPIOS  "
# print(texto.strip().lower().replace("limpios","ordenados"))
# prod, precio = "Café", 3200
# print(f"Mi producto favorito es {prod} y cuesta {precio} pesos")
# ```
#
# **(3)**
# ```python
# frutas = ["manzana","pera","banano","uva","mango"]
# frutas.append("kiwi")
# frutas.sort()
# print(frutas[0], frutas[-1])
#
# lista = ["a","b","a","c","b"]
# s = set(lista)
# print(len(s))
#
# precios = {"cafe": 3000, "pan": 2000, "arroz": 4500}
# precios_inc = {k: round(v*1.10, 2) for k,v in precios.items()}
# print(precios_inc)
# ```
#
# **(4)**
# ```python
# edad = 34
# if edad < 12:
#     print("niño")
# elif edad <= 17:
#     print("adolescente")
# elif edad <= 64:
#     print("adulto")
# else:
#     print("mayor")
#
# for n in range(1, 101):
#     if n % 15 == 0:
#         print("FizzBuzz")
#     elif n % 3 == 0:
#         print("Fizz")
#     elif n % 5 == 0:
#         print("Buzz")
#     else:
#         print(n)
# ```
#
# **(5)**
# ```python
# def es_par(n): return n % 2 == 0
#
# def promedio(lista):
#     return sum(lista)/len(lista) if lista else 0
#
# def contar_palabras(texto):
#     d = {}
#     for p in texto.lower().split():
#         d[p] = d.get(p, 0) + 1
#     return d
# ```
#
# **(6)**
# ```python
# import math, random
# radio = 7
# area = math.pi * radio**2
#
# caras = sum(1 for _ in range(10) if random.choice([True, False]))
# cruces = 10 - caras
# print(area, caras, cruces)
# ```
#
# **(7)**
# ```python
# def leer_entero(texto):
#     try:
#         return int(texto)
#     except ValueError:
#         print("No es un número entero válido.")
#         return None
# ```
# </details>
#
# <details>
# <summary><strong>Mini-quiz</strong></summary>
#
# 1) `input()` devuelve **str**.
# 2) La **lista** es mutable; la **tupla** es inmutable.
# 3) Para capturar y manejar errores sin que el programa se detenga.
# 4) `[n**3 for n in range(6)]`
# 5) `<class 'bool'>`
# </details>
